# %% [markdown]
# # Solução — VRP Pickup & Delivery (exemplo)
#
# Notebook mínimo que carrega `solver.py` e executa o exemplo em `data/data.json`.

# %%
# !git clone https://github.com/natanpt/atividade_po.git

# %%
import sys
import json
from pathlib import Path
from atividade_po.solver import *

data = create_data_model_from_json('atividade_po/data/data.json')
print('Dados carregados:')
print(json.dumps(data, indent=2))
try:
    solve(data)
except Exception as e:
    print('Erro ao rodar solver:', e)
